# %%
import pandas as pd
df=pd.read_csv("EduData.csv")

df
# Out:
#     gender PlaceofBirth  ... ParentschoolSatisfaction StudentAbsenceDays
# 0        M       KuwaIT  ...                     Good            Under-7
# 1        M       KuwaIT  ...                     Good            Under-7
# 2        M       KuwaIT  ...                      Bad            Above-7
# 3        M       KuwaIT  ...                      Bad            Above-7
# 4        M       KuwaIT  ...                      Bad            Above-7
# ..     ...          ...  ...                      ...                ...
# 475      F       Jordan  ...                      Bad            Above-7
# 476      F       Jordan  ...                      Bad            Under-7
# 477      F       Jordan  ...                      Bad            Under-7
# 478      F       Jordan  ...                      Bad            Above-7
# 479      F       Jordan  ...                      Bad            Above-7
#
# [480 rows x 13 columns]

# %%
#Normalization
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()

# %%
scaling.fit_transform(df[['raisedhands','Discussion']])
# Out:
# array([[0.15      , 0.19387755],
#        [0.2       , 0.24489796],
#        [0.1       , 0.29591837],
#        [0.3       , 0.34693878],
#        [0.4       , 0.5       ],
#        [0.42      , 0.70408163],
#        [0.35      , 0.16326531],
#        [0.5       ,        nan],
#        [0.12      , 0.5       ],
#        [0.7       , 0.70408163],
#        [0.5       , 0.80612245],
#        [0.19      , 0.1122449 ],
#        [0.05      , 0.10204082],
#        [0.2       , 0.18367347],
#        [0.62      , 0.60204082],
#        [0.3       , 0.66326531],
#        [0.36      , 0.80612245],
#        [0.55      , 0.90816327],
#        [0.69      , 0.96938776],
#        [0.7       , 1.        ],
#        [0.6       , 0.90816327],
#        [0.1       , 0.80612245],
#        [       nan, 0.90816327],
#        [0.02      , 0.5       ],
#        [0.        , 0.70408163],
#        [0.08      , 0.39795918],
#        [0.19      , 0.39795918],
#        [0.25      , 0.32653061],
# ...

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

stdscaling=StandardScaler()

# %%
stdscaling.fit_transform(df[['raisedhands','Discussion']])
# Out:
# array([[-1.06358349, -0.86110692],
#        [-0.90094   , -0.68039315],
#        [-1.22622698, -0.49967937],
#        [-0.57565302, -0.31896559],
#        [-0.25036604,  0.22317573],
#        [-0.18530865,  0.94603084],
#        [-0.41300953, -0.96953519],
#        [ 0.07492094,         nan],
#        [-1.16116959,  0.22317573],
#        [ 0.7254949 ,  0.94603084],
#        [ 0.07492094,  1.30745839],
#        [-0.9334687 , -1.15024896],
#        [-1.38887047, -1.18639172],
#        [-0.90094   , -0.89724968],
#        [ 0.46526531,  0.58460328],
#        [-0.57565302,  0.80145982],
#        [-0.38048083,  1.30745839],
#        [ 0.23756443,  1.66888594],
#        [ 0.6929662 ,  1.88574247],
#        [ 0.7254949 ,  1.99417074],
#        [ 0.40020792,  1.66888594],
#        [-1.22622698,  1.30745839],
#        [        nan,  1.66888594],
#        [-1.48645656,  0.22317573],
#        [-1.55151396,  0.94603084],
#        [-1.29128438, -0.13825182],
#        [-0.9334687 , -0.13825182],
# ...

# %%
#One Hot Encoding
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer 
import numpy as np

enc = ColumnTransformer( [('encoder', OneHotEncoder(), [0])], remainder='passthrough')

# %%
new = pd.DataFrame(data=enc.fit_transform(df),columns=['F', 'M',	'PlaceofBirth',	'StageID',	'GradeID', 'Topic'	,'Relation',	'raisedhands',	'VisITedResources'	,'AnnouncementsView','Discussion'	,'ParentAnsweringSurvey',	'ParentschoolSatisfaction',	'StudentAbsenceDays'])

new
# Out:
#      F  M  ... ParentschoolSatisfaction StudentAbsenceDays
# 0    0  1  ...                     Good            Under-7
# 1    0  1  ...                     Good            Under-7
# 2    0  1  ...                      Bad            Above-7
# 3    0  1  ...                      Bad            Above-7
# 4    0  1  ...                      Bad            Above-7
# ..  .. ..  ...                      ...                ...
# 475  1  0  ...                      Bad            Above-7
# 476  1  0  ...                      Bad            Under-7
# 477  1  0  ...                      Bad            Under-7
# 478  1  0  ...                      Bad            Above-7
# 479  1  0  ...                      Bad            Above-7
#
# [480 rows x 14 columns]

# %%
#Imputing missing values
from sklearn.impute import KNNImputer

data=pd.read_csv("EduData.csv",usecols=['raisedhands','VisITedResources','AnnouncementsView','Discussion'])
data
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion
# 0           15.0              16.0                2.0        20.0
# 1           20.0              20.0                3.0        25.0
# 2           10.0               7.0                0.0        30.0
# 3           30.0              25.0                5.0        35.0
# 4           40.0              50.0               12.0        50.0
# ..           ...               ...                ...         ...
# 475          5.0               4.0                NaN         8.0
# 476         50.0              77.0               14.0         NaN
# 477         55.0              74.0                NaN        29.0
# 478          NaN              17.0               14.0        57.0
# 479          NaN              14.0               23.0        62.0
#
# [480 rows x 4 columns]

# %%
missingdata=data.replace(0,np.nan)
imputer = KNNImputer(n_neighbors=10, weights="uniform")
arr = imputer.fit_transform(missingdata)

# %%
new = pd.DataFrame(data = arr, columns = ['raisedhands','VisITedResources','AnnouncementsView','Discussion'])
new
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion
# 0           15.0              16.0                2.0        20.0
# 1           20.0              20.0                3.0        25.0
# 2           10.0               7.0               15.1        30.0
# 3           30.0              25.0                5.0        35.0
# 4           40.0              50.0               12.0        50.0
# ..           ...               ...                ...         ...
# 475          5.0               4.0                9.0         8.0
# 476         50.0              77.0               14.0        39.1
# 477         55.0              74.0               40.6        29.0
# 478         26.4              17.0               14.0        57.0
# 479         30.5              14.0               23.0        62.0
#
# [480 rows x 4 columns]
